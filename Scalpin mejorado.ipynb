# %%
# Importamos librerias
import yfinance as yf
import talib as ta
from talib import BBANDS
import pandas as pd
import numpy as np
import pandas_datareader as pdr
import matplotlib.pyplot as plt
import datetime
# Se carga la información de una accion o activo desde Yahoo Finance a una Variable
activo = yf.Ticker("BTC-USD")
precios = activo.history(period="1mo", interval="5m")
close = precios['Close'].to_numpy()
up, mid, low = BBANDS(close, timeperiod=25, nbdevup=2, nbdevdn=2, matype=0)
precios['RSI'] = ta.RSI(precios['Close'].values).astype(float)
def alertaBoll(B, amplitud, alertaPercentil, RSI):
    try:
        if B > 1 and alertaPercentil < amplitud and df['RSI'] > 70:
            alerta = "SobreCompra"
        elif B < 0 and alertaPercentil < amplitud and df['RSI'] < 30:
            alerta = "SobreVenta"
        elif B > 1:
            alerta = "Sobre Banda Superior sin volatilidad"
        elif B < 0:
            alerta = "Debajo Banda Inferior sin Volatilidad"
        else:
            alerta = "Sin Señal"
        return alerta
    except Exception as e:
        return str(e)
def bbp(price):
    up, mid, low = BBANDS(price, timeperiod=20, nbdevup=2, nbdevdn=2, matype=0)
    bbp = (price - low) / (up - low)
    return bbp
BollBeta = bbp(close)
precios['UP'] = up.tolist()
precios['MID'] = mid.tolist()
precios['DOWN'] = low.tolist()
precios['B'] = BollBeta.tolist()
precios['AMPLITUD'] = precios['UP'] / precios['DOWN'] - 1

precios['AMPLITUD'].plot()
precios['AMPLITUD'].hist(bins=100)

precios = precios[precios['AMPLITUD'] < 1]

precios['AMPLITUD'].plot()
precios['AMPLITUD'].hist(bins=100)
alertaPercentil = np.percentile(precios['AMPLITUD'], 90)

precios['Alerta']  = precios.apply(lambda x: alertaBoll(x['B'], x['AMPLITUD'], alertaPercentil, x['RSI']), axis=1)
import datetime

fechaLimite = datetime.datetime.now() - datetime.timedelta(days=5*365)
fechaLimite = np.datetime64(fechaLimite)
fechaLimite

precios.dtypes
precios['date'] = precios.index
precios.dtypes
precios['date'] = precios['date'].dt.tz_localize(None)
precios.dtypes


precios = precios[precios['date'] > fechaLimite]

precios['AMPLITUD'].plot()
precios['AMPLITUD'].hist(bins=100)


# Encontrar el percentil 90
alertaPercentil = np.percentile(precios['AMPLITUD'], 90)
# Traer últimos 30 datos para caluclar parámetros de banda
# Si el porcentaje B es negativo o superior a 1 y la amplitud es mayor al 95% se da alerta

preciosHoy = activo.history(period="1mo", interval="5m")
close = preciosHoy['Close'].to_numpy()

# Se calculan las bandas de bollinger
up, mid, low = BBANDS(close, timeperiod=20, nbdevup=2, nbdevdn=2, matype=0)

BollBeta = bbp(close)


preciosHoy['UP'] = up.tolist()
preciosHoy['MID'] = mid.tolist()
preciosHoy['DOWN'] = low.tolist()
preciosHoy['B'] = BollBeta.tolist()

preciosHoy['AMPLITUD'] = preciosHoy['UP'] / preciosHoy['DOWN'] - 1

preciosHoy['Alerta']  = preciosHoy.apply(lambda x: alertaBoll(x['B'], x['AMPLITUD'], alertaPercentil, precios['RSI']), axis=1)
preciosHoy.tail(n=30)
# Out:
#                                    Open          High           Low  \
# Datetime
# 2023-01-30 11:40:00+00:00  23232.455078  23232.455078  23169.746094
# 2023-01-30 11:45:00+00:00  23176.845703  23195.839844  23176.845703
# 2023-01-30 11:50:00+00:00  23170.070312  23170.070312  23127.857422
# 2023-01-30 11:55:00+00:00  23121.681641  23121.681641  23111.275391
# 2023-01-30 12:00:00+00:00  23117.896484  23120.173828  23093.884766
# 2023-01-30 12:05:00+00:00  23130.843750  23145.785156  23130.843750
# 2023-01-30 12:10:00+00:00  23132.902344  23132.902344  23121.804688
# 2023-01-30 12:15:00+00:00  23128.705078  23138.880859  23128.705078
# 2023-01-30 12:20:00+00:00  23142.755859  23142.964844  23138.083984
# 2023-01-30 12:25:00+00:00  23134.593750  23134.593750  23112.968750
# 2023-01-30 12:30:00+00:00  23118.416016  23141.146484  23118.416016
# 2023-01-30 12:35:00+00:00  23137.419922  23138.693359  23113.685547
# 2023-01-30 12:40:00+00:00  23093.306641  23093.306641  23045.876953
# 2023-01-30 12:45:00+00:00  23041.855469  23072.369141  23041.855469
# 2023-01-30 12:50:00+00:00  23074.560547  23074.560547  23070.037109
# 2023-01-30 12:55:00+00:00  23068.996094  23082.687500  23066.787109
# 2023-01-30 13:00:00+00:00  23083.880859  23094.501953  23082.035156
# 2023-01-30 13:05:00+00:00  23095.509766  23095.589844  23088.845703
# 2023-01-30 13:10:00+00:00  23103.644531  23116.480469  23103.644531
# 2023-01-30 13:15:00+00:00  23118.740234  23124.677734  23118.740234
# 2023-01-30 13:20:00+00:00  23121.976562  23121.976562  23115.482422
# 2023-01-30 13:25:00+00:00  23118.791016  23119.486328  23114.396484
# 2023-01-30 13:30:00+00:00  23123.023438  23130.181641  23117.291016
# 2023-01-30 13:35:00+00:00  23112.396484  23114.435547  23100.884766
# 2023-01-30 13:40:00+00:00  23104.250000  23106.246094  23098.105469
# 2023-01-30 13:45:00+00:00  23108.783203  23115.794922  23108.783203
# 2023-01-30 13:50:00+00:00  23109.396484  23114.755859  23109.396484
# 2023-01-30 13:55:00+00:00  23102.392578  23102.392578  23086.570312
# 2023-01-30 14:00:00+00:00  23085.548828  23085.548828  23067.935547
# 2023-01-30 14:05:00+00:00  23070.998047  23070.998047  23070.998047
#
#                                   Close     Volume  Dividends  Stock Splits  \
# Datetime
# 2023-01-30 11:40:00+00:00  23170.025391  165847040        0.0           0.0
# 2023-01-30 11:45:00+00:00  23178.937500  193968128        0.0           0.0
# 2023-01-30 11:50:00+00:00  23127.857422   32786432        0.0           0.0
# 2023-01-30 11:55:00+00:00  23115.617188  106921984        0.0           0.0
# 2023-01-30 12:00:00+00:00  23120.173828   47427584        0.0           0.0
# 2023-01-30 12:05:00+00:00  23141.958984  131151872        0.0           0.0
# 2023-01-30 12:10:00+00:00  23124.261719   48046080        0.0           0.0
# 2023-01-30 12:15:00+00:00  23138.880859   27932672        0.0           0.0
# 2023-01-30 12:20:00+00:00  23138.083984   14338048        0.0           0.0
# 2023-01-30 12:25:00+00:00  23112.968750   15474688        0.0           0.0
# 2023-01-30 12:30:00+00:00  23141.146484   81152000        0.0           0.0
# 2023-01-30 12:35:00+00:00  23113.771484   33961984        0.0           0.0
# 2023-01-30 12:40:00+00:00  23045.876953  144947200        0.0           0.0
# 2023-01-30 12:45:00+00:00  23072.369141    2883584        0.0           0.0
# 2023-01-30 12:50:00+00:00  23070.037109          0        0.0           0.0
# 2023-01-30 12:55:00+00:00  23082.687500          0        0.0           0.0
# 2023-01-30 13:00:00+00:00  23094.501953    5419008        0.0           0.0
# 2023-01-30 13:05:00+00:00  23093.980469          0        0.0           0.0
# 2023-01-30 13:10:00+00:00  23116.480469    7692288        0.0           0.0
# 2023-01-30 13:15:00+00:00  23124.677734          0        0.0           0.0
# 2023-01-30 13:20:00+00:00  23119.244141          0        0.0           0.0
# 2023-01-30 13:25:00+00:00  23119.486328     143360        0.0           0.0
# 2023-01-30 13:30:00+00:00  23117.291016          0        0.0           0.0
# 2023-01-30 13:35:00+00:00  23100.884766          0        0.0           0.0
# 2023-01-30 13:40:00+00:00  23106.246094     274432        0.0           0.0
# 2023-01-30 13:45:00+00:00  23113.375000          0        0.0           0.0
# 2023-01-30 13:50:00+00:00  23111.208984          0        0.0           0.0
# 2023-01-30 13:55:00+00:00  23086.570312          0        0.0           0.0
# 2023-01-30 14:00:00+00:00  23067.935547    1050624        0.0           0.0
# 2023-01-30 14:05:00+00:00  23070.998047          0        0.0           0.0
#
#                                      UP           MID          DOWN         B  \
# Datetime
# 2023-01-30 11:40:00+00:00  23309.009106  23255.358398  23201.707691 -0.295265
# 2023-01-30 11:45:00+00:00  23315.184039  23252.816113  23190.448188 -0.092281
# 2023-01-30 11:50:00+00:00  23329.460609  23246.637793  23163.814977 -0.217075
# 2023-01-30 11:55:00+00:00  23340.167521  23239.716797  23139.266073 -0.117714
# 2023-01-30 12:00:00+00:00  23342.738195  23231.652832  23120.567469 -0.001772
# 2023-01-30 12:05:00+00:00  23339.474869  23224.562695  23109.650521  0.140579
# 2023-01-30 12:10:00+00:00  23334.714764  23216.206152  23097.697541  0.112077
# 2023-01-30 12:15:00+00:00  23327.631034  23208.920215  23090.209395  0.205000
# 2023-01-30 12:20:00+00:00  23320.001067  23201.920215  23083.839363  0.229693
# 2023-01-30 12:25:00+00:00  23312.549617  23193.709473  23074.869329  0.160297
# 2023-01-30 12:30:00+00:00  23308.102907  23188.911133  23069.719359  0.299631
# 2023-01-30 12:35:00+00:00  23304.826265  23183.026465  23061.226664  0.215702
# 2023-01-30 12:40:00+00:00  23304.285814  23172.820020  23041.354225  0.017201
# 2023-01-30 12:45:00+00:00  23294.373685  23163.168750  23031.963815  0.153978
# 2023-01-30 12:50:00+00:00  23281.669564  23153.379297  23025.089030  0.175181
# 2023-01-30 12:55:00+00:00  23264.791790  23144.175879  23023.559968  0.245107
# 2023-01-30 13:00:00+00:00  23251.063691  23136.938672  23022.813653  0.314078
# 2023-01-30 13:05:00+00:00  23230.920027  23128.940625  23026.961223  0.328592
# 2023-01-30 13:10:00+00:00  23205.409099  23121.928906  23038.448714  0.467367
# 2023-01-30 13:15:00+00:00  23180.250267  23116.214746  23052.179225  0.566080
# 2023-01-30 13:20:00+00:00  23172.815171  23113.675684  23054.536196  0.547079
# 2023-01-30 13:25:00+00:00  23161.860396  23110.703125  23059.545854  0.585845
# 2023-01-30 13:30:00+00:00  23160.828294  23110.174805  23059.521316  0.570244
# 2023-01-30 13:35:00+00:00  23160.182075  23109.438184  23058.694292  0.415720
# 2023-01-30 13:40:00+00:00  23159.259020  23108.741797  23058.224574  0.475298
# 2023-01-30 13:45:00+00:00  23155.556109  23107.312598  23059.069086  0.562831
# 2023-01-30 13:50:00+00:00  23154.318270  23106.659961  23059.001651  0.547725
# 2023-01-30 13:55:00+00:00  23150.055650  23104.044434  23058.033217  0.310110
# 2023-01-30 14:00:00+00:00  23146.328454  23100.537012  23054.745570  0.144022
# 2023-01-30 14:05:00+00:00  23145.585494  23098.438477  23051.291459  0.208991
#
#                            AMPLITUD                                 Alerta
# Datetime
# 2023-01-30 11:40:00+00:00  0.004625  Debajo Banda Inferior sin Volatilidad
# 2023-01-30 11:45:00+00:00  0.005379  Debajo Banda Inferior sin Volatilidad
# 2023-01-30 11:50:00+00:00  0.007151  Debajo Banda Inferior sin Volatilidad
# 2023-01-30 11:55:00+00:00  0.008682  Debajo Banda Inferior sin Volatilidad
# 2023-01-30 12:00:00+00:00  0.009609  Debajo Banda Inferior sin Volatilidad
# 2023-01-30 12:05:00+00:00  0.009945                              Sin Señal
# 2023-01-30 12:10:00+00:00  0.010262                              Sin Señal
# 2023-01-30 12:15:00+00:00  0.010282                              Sin Señal
# 2023-01-30 12:20:00+00:00  0.010231                              Sin Señal
# 2023-01-30 12:25:00+00:00  0.010300                              Sin Señal
# 2023-01-30 12:30:00+00:00  0.010333                              Sin Señal
# 2023-01-30 12:35:00+00:00  0.010563                              Sin Señal
# 2023-01-30 12:40:00+00:00  0.011411                              Sin Señal
# 2023-01-30 12:45:00+00:00  0.011393                              Sin Señal
# 2023-01-30 12:50:00+00:00  0.011144                              Sin Señal
# 2023-01-30 12:55:00+00:00  0.010478                              Sin Señal
# 2023-01-30 13:00:00+00:00  0.009914                              Sin Señal
# 2023-01-30 13:05:00+00:00  0.008857                              Sin Señal
# 2023-01-30 13:10:00+00:00  0.007247                              Sin Señal
# 2023-01-30 13:15:00+00:00  0.005556                              Sin Señal
# 2023-01-30 13:20:00+00:00  0.005130                              Sin Señal
# 2023-01-30 13:25:00+00:00  0.004437                              Sin Señal
# 2023-01-30 13:30:00+00:00  0.004393                              Sin Señal
# 2023-01-30 13:35:00+00:00  0.004401                              Sin Señal
# 2023-01-30 13:40:00+00:00  0.004382                              Sin Señal
# 2023-01-30 13:45:00+00:00  0.004184                              Sin Señal
# 2023-01-30 13:50:00+00:00  0.004134                              Sin Señal
# 2023-01-30 13:55:00+00:00  0.003991                              Sin Señal
# 2023-01-30 14:00:00+00:00  0.003972                              Sin Señal
# 2023-01-30 14:05:00+00:00  0.004091                              Sin Señal
